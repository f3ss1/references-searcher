# %%
# %load_ext autoreload
# %autoreload 2

# %%
from sqlalchemy import create_engine, text
import pandas as pd
from sklearn.model_selection import train_test_split


from citations_searcher.constants import POSTGRES_URL

# Create an engine
engine = create_engine(POSTGRES_URL)

# %%
positive_query = "SELECT * FROM joined_filtered_positive_references"
negative_query = "SELECT * FROM joined_filtered_negative_references"
metadata_query = "SELECT * FROM train_references_metadata"

with engine.connect() as conn:
    positive_df = pd.read_sql_query(text(positive_query), conn)
    negative_df = pd.read_sql_query(text(negative_query), conn)
    metadata_df = pd.read_sql_query(text(metadata_query), conn)

print(len(positive_df), len(negative_df), len(metadata_df))
positive_df.head()
# Out:
# 309626 219260 54163
#   paper_arxiv_id                                        paper_title  \
# 0     2201.02217  nonlocal kernel network (nkn): a stable and re...
# 1     2002.00585  proving the lottery ticket hypothesis: pruning...
# 2     2003.11755  a survey of deep learning for scientific disco...
# 3     2006.15057  a loss function for generative neural networks...
# 4     2102.10739  dissecting the diffusion process in linear gra...
#
#                                       paper_abstract  \
# 0  neural operators have recently become popular ...
# 1  the lottery ticket hypothesis (frankle and car...
# 2  over the past few years, we have seen fundamen...
# 3  to train variational autoencoders (vaes) to ge...
# 4  graph convolutional networks (gcns) have attra...
#
#                                           paper_tldr reference_arxiv_id  \
# 0  This work proposes a novel nonlocal neural ope...         2004.00361
# 1  An even stronger hypothesis is proved, showing...         1811.03804
# 2  This survey provides an overview of many widel...         1807.03748
# 3  A loss function based on Watson's perceptual m...          1412.6980
# 4  This paper dissects the feature propagation st...          1412.6980
#
#        reference_date                                    reference_title  \
# 0 2020-08-11 15:43:51  eikonet: solving the eikonal equation with dee...
# 1 2019-05-28 19:01:22  gradient descent finds global minima of deep n...
# 2 2019-01-22 18:47:12  representation learning with contrastive predi...
# 3 2017-01-30 01:27:54         adam: a method for stochastic optimization
# 4 2017-01-30 01:27:54         adam: a method for stochastic optimization
#
#                                    reference_authors  \
# 0  jonathan d. smith, kamyar azizzadenesheli, zac...
# 1  simon s. du, jason d. lee, haochuan li, liwei ...
# 2        aaron van den oord, yazhe li, oriol vinyals
# 3                       diederik p. kingma, jimmy ba
# 4                       diederik p. kingma, jimmy ba
#
#                                   reference_abstract reference_category_1  \
# 0  the recent deep learning revolution has create...      physics.comp-ph
# 1  gradient descent finds a global minimum in tra...                cs.lg
# 2  while supervised learning has enabled great pr...                cs.lg
# 3  we introduce adam, an algorithm for first-orde...                cs.lg
# 4  we introduce adam, an algorithm for first-orde...                cs.lg
#
#   reference_category_2  reference_citation_count  \
# 0                cs.lg                      94.0
# 1                cs.ai                    1002.0
# 2              stat.ml                    7563.0
# 3                 None                  133232.0
# 4                 None                  133232.0
#
#    reference_influential_citation_count  \
# 0                                   6.0
# 1                                 140.0
# 2                                1105.0
# 3                               21032.0
# 4                               21032.0
#
#                                       reference_tldr
# 0  EikoNet is a deep learning approach to solving...
# 1  The current paper proves gradient descent achi...
# 2  This work proposes a universal unsupervised le...
# 3  This work introduces Adam, an algorithm for fi...
# 4  This work introduces Adam, an algorithm for fi...

# %%
positive_df['target'] = 1
negative_df['target'] = 0

overall_df = result = pd.concat([positive_df, negative_df], ignore_index=True)
print(len(overall_df))
overall_df.head()
# Out:
# 528886
#   paper_arxiv_id                                        paper_title  \
# 0     2201.02217  nonlocal kernel network (nkn): a stable and re...
# 1     2002.00585  proving the lottery ticket hypothesis: pruning...
# 2     2003.11755  a survey of deep learning for scientific disco...
# 3     2006.15057  a loss function for generative neural networks...
# 4     2102.10739  dissecting the diffusion process in linear gra...
#
#                                       paper_abstract  \
# 0  neural operators have recently become popular ...
# 1  the lottery ticket hypothesis (frankle and car...
# 2  over the past few years, we have seen fundamen...
# 3  to train variational autoencoders (vaes) to ge...
# 4  graph convolutional networks (gcns) have attra...
#
#                                           paper_tldr reference_arxiv_id  \
# 0  This work proposes a novel nonlocal neural ope...         2004.00361
# 1  An even stronger hypothesis is proved, showing...         1811.03804
# 2  This survey provides an overview of many widel...         1807.03748
# 3  A loss function based on Watson's perceptual m...          1412.6980
# 4  This paper dissects the feature propagation st...          1412.6980
#
#        reference_date                                    reference_title  \
# 0 2020-08-11 15:43:51  eikonet: solving the eikonal equation with dee...
# 1 2019-05-28 19:01:22  gradient descent finds global minima of deep n...
# 2 2019-01-22 18:47:12  representation learning with contrastive predi...
# 3 2017-01-30 01:27:54         adam: a method for stochastic optimization
# 4 2017-01-30 01:27:54         adam: a method for stochastic optimization
#
#                                    reference_authors  \
# 0  jonathan d. smith, kamyar azizzadenesheli, zac...
# 1  simon s. du, jason d. lee, haochuan li, liwei ...
# 2        aaron van den oord, yazhe li, oriol vinyals
# 3                       diederik p. kingma, jimmy ba
# 4                       diederik p. kingma, jimmy ba
#
#                                   reference_abstract reference_category_1  \
# 0  the recent deep learning revolution has create...      physics.comp-ph
# 1  gradient descent finds a global minimum in tra...                cs.lg
# 2  while supervised learning has enabled great pr...                cs.lg
# 3  we introduce adam, an algorithm for first-orde...                cs.lg
# 4  we introduce adam, an algorithm for first-orde...                cs.lg
#
#   reference_category_2  reference_citation_count  \
# 0                cs.lg                      94.0
# 1                cs.ai                    1002.0
# 2              stat.ml                    7563.0
# 3                 None                  133232.0
# 4                 None                  133232.0
#
#    reference_influential_citation_count  \
# 0                                   6.0
# 1                                 140.0
# 2                                1105.0
# 3                               21032.0
# 4                               21032.0
#
#                                       reference_tldr  target
# 0  EikoNet is a deep learning approach to solving...       1
# 1  The current paper proves gradient descent achi...       1
# 2  This work proposes a universal unsupervised le...       1
# 3  This work introduces Adam, an algorithm for fi...       1
# 4  This work introduces Adam, an algorithm for fi...       1

# %%
overall_df.loc[:, 'reference_category_1'] = overall_df['reference_category_1'].fillna('')
overall_df.loc[:, 'reference_category_2'] = overall_df['reference_category_2'].fillna('')

# %%
overall_df = overall_df[
    [
        "paper_title",
        "paper_abstract",
        "reference_title",
        "reference_abstract",
        "reference_category_1",
        "reference_category_2",
        "reference_citation_count",
        "reference_influential_citation_count",
        "target",
    ]
]
X_train, X_test, y_train, y_test = train_test_split(
    overall_df.drop(columns=['target']), # Drop the target column from the input features
    overall_df['target'],                # The target column
    test_size=0.2,               # Specify the size of the test set
    random_state=42,             # A seed value for reproducibility
    stratify=overall_df['target']  # Use the combined column for stratification
)

# %%
X_train
# Out:
#                                               paper_title  \
# 164793  residual pathway priors for soft equivariance ...
# 377136  clusterability as an alternative to anchor poi...
# 158387  characterizing attacks on deep reinforcement l...
# 69588   scalable algorithms for physics-informed neura...
# 514587  robust pdf document conversion using recurrent...
# ...                                                   ...
# 210238        fair learning with private demographic data
# 172768  robust and differentially private mean estimation
# 21909   flambe: structural complexity and representati...
# 246269  early-learning regularization prevents memoriz...
# 357690          bayesian counterfactual risk minimization
#
#                                            paper_abstract  \
# 164793  there is often a trade-off between building de...
# 377136  the label noise transition matrix, characteriz...
# 158387  recent studies show that deep reinforcement le...
# 69588   physics-informed machine learning (piml) has e...
# 514587  the number of published pdf documents has incr...
# ...                                                   ...
# 210238  sensitive attributes such as race are rarely a...
# 172768  in statistical learning and analysis from shar...
# 21909   in order to deal with the curse of dimensional...
# 246269  we propose a novel framework to perform classi...
# 357690  we present a bayesian view of counterfactual r...
#
#                                           reference_title  \
# 164793  mdp homomorphic networks: group symmetries in ...
# 377136  skip-clip: self-supervised spatiotemporal repr...
# 158387     playing atari with deep reinforcement learning
# 69588   nvidia simnet^{tm}: an ai-accelerated multi-ph...
# 514587  oxford handbook on ai ethics book chapter on r...
# ...                                                   ...
# 210238                         fairness through awareness
# 172768             fast implementation of the tukey depth
# 21909   curiosity-driven exploration by self-supervise...
# 246269      iterative learning with open-set noisy labels
# 357690  alphanet: improved training of supernets with ...
#
#                                        reference_abstract  \
# 164793  this paper introduces mdp homomorphic networks...
# 377136  deep neural networks require collecting and an...
# 158387  we present the first deep learning model to su...
# 69588   we present simnet, an ai-driven multi-physics ...
# 514587  from massive face-recognition-based surveillan...
# ...                                                   ...
# 210238  we study fairness in classification, where ind...
# 172768  tukey depth function is one of the most famous...
# 21909   in many real-world scenarios, rewards extrinsi...
# 246269  large-scale datasets possessing clean label an...
# 357690  weight-sharing neural architecture search (nas...
#
#        reference_category_1 reference_category_2  reference_citation_count  \
# 164793                cs.lg              stat.ml                     116.0
# 377136                cs.cv                                           15.0
# 158387                cs.lg                                        10374.0
# 69588       physics.flu-dyn                cs.lg                     116.0
# 514587                cs.cy                cs.ai                      29.0
# ...                     ...                  ...                       ...
# 210238                cs.cc                cs.cy                    3180.0
# 172768              stat.co                                           15.0
# 21909                 cs.lg                cs.ai                    2058.0
# 246269                cs.cv                                          287.0
# 357690                cs.cv                cs.ai                      33.0
#
#         reference_influential_citation_count
# 164793                                   9.0
# 377136                                   0.0
# 158387                                1320.0
# 69588                                   13.0
# 514587                                   0.0
# ...                                      ...
# 210238                                 410.0
# 172768                                   0.0
# 21909                                  286.0
# 246269                                  29.0
# 357690                                   3.0
#
# [423108 rows x 8 columns]

# %%
# Assuming X_train is already defined and has the columns 'reference_category_1' and 'reference_category_2'
all_categories = pd.concat([X_train['reference_category_1'], X_train['reference_category_2']])
category_counts = all_categories.value_counts()

# Find infrequent categories where count is less than the threshold
threshold = 10_000
infrequent_categories = category_counts[category_counts < threshold].index

# Convert infrequent categories to a set for faster checking
infrequent_categories_set = set(infrequent_categories)

# Create a mask where categories are infrequent
mask_1 = X_train['reference_category_1'].isin(infrequent_categories_set)
mask_2 = X_train['reference_category_2'].isin(infrequent_categories_set)

# Use where or mask to replace
X_train['reference_category_1'] = X_train['reference_category_1'].where(~mask_1, other='other')
X_train['reference_category_2'] = X_train['reference_category_2'].where(~mask_2, other='other')

# Create a mask where categories are infrequent
mask_1 = X_test['reference_category_1'].isin(infrequent_categories_set)
mask_2 = X_test['reference_category_2'].isin(infrequent_categories_set)

# Use where or mask to replace
X_test['reference_category_1'] = X_test['reference_category_1'].where(~mask_1, other='other')
X_test['reference_category_2'] = X_test['reference_category_2'].where(~mask_2, other='other')

X_train.head()
# Out:
#                                               paper_title  \
# 164793  residual pathway priors for soft equivariance ...
# 377136  clusterability as an alternative to anchor poi...
# 158387  characterizing attacks on deep reinforcement l...
# 69588   scalable algorithms for physics-informed neura...
# 514587  robust pdf document conversion using recurrent...
#
#                                            paper_abstract  \
# 164793  there is often a trade-off between building de...
# 377136  the label noise transition matrix, characteriz...
# 158387  recent studies show that deep reinforcement le...
# 69588   physics-informed machine learning (piml) has e...
# 514587  the number of published pdf documents has incr...
#
#                                           reference_title  \
# 164793  mdp homomorphic networks: group symmetries in ...
# 377136  skip-clip: self-supervised spatiotemporal repr...
# 158387     playing atari with deep reinforcement learning
# 69588   nvidia simnet^{tm}: an ai-accelerated multi-ph...
# 514587  oxford handbook on ai ethics book chapter on r...
#
#                                        reference_abstract  \
# 164793  this paper introduces mdp homomorphic networks...
# 377136  deep neural networks require collecting and an...
# 158387  we present the first deep learning model to su...
# 69588   we present simnet, an ai-driven multi-physics ...
# 514587  from massive face-recognition-based surveillan...
#
#        reference_category_1 reference_category_2  reference_citation_count  \
# 164793                cs.lg              stat.ml                     116.0
# 377136                cs.cv                                           15.0
# 158387                cs.lg                                        10374.0
# 69588                 other                cs.lg                     116.0
# 514587                other                cs.ai                      29.0
#
#         reference_influential_citation_count
# 164793                                   9.0
# 377136                                   0.0
# 158387                                1320.0
# 69588                                   13.0
# 514587                                   0.0

# %%
metadata_df.head()
# Out:
#      arxiv_id                date  \
# 0  1906.05059 2019-06-12 11:07:10
# 1  1906.05774 2019-10-08 14:44:59
# 2  1801.05772 2018-01-17 17:44:48
# 3  1906.05795 2019-06-13 16:29:30
# 4  1906.05797 2019-06-13 16:29:58
#
#                                                title  \
# 0  higher-order ranking and link prediction: from...
# 1  deep unfolding for communications systems: a s...
# 2  ranking data with continuous labels through or...
# 3  topological data analysis for arrhythmia detec...
# 4  the replica dataset: a digital replica of indo...
#
#                                              authors  \
# 0  ryan a. rossi, anup rao, sungchul kim, eunyee ...
# 1     alexios balatsoukas-stimming, christoph studer
# 2                   stephan clemencon, mastane achab
# 3        meryll dindin, yuhei umeda, frederic chazal
# 4  julian straub, thomas whelan, lingni ma, yufan...
#
#                                             abstract category_1 category_2  \
# 0  in this paper, we introduce the notion of moti...      cs.lg      cs.ir
# 1  deep unfolding is a method of growing populari...    eess.sp      cs.it
# 2  we formulate a supervised learning problem, re...    stat.ml       None
# 3  this paper presents an innovative and generic ...      cs.lg    eess.sp
# 4  we introduce replica, a dataset of 18 highly p...      cs.cv      cs.gr
#
#    citation_count  influential_citation_count  \
# 0            17.0                         2.0
# 1           155.0                         7.0
# 2             6.0                         4.0
# 3            37.0                         2.0
# 4           511.0                       117.0
#
#                                                 tldr
# 0  Higher-order network motifs are investigated a...
# 1  This survey summarizes the principle of deep u...
# 2                                               None
# 3  An innovative and generic deep learning approa...
# 4  Replica, a dataset of 18 highly photo-realisti...

# %%
from citations_searcher.models import CustomCatboostClassifier

# %%
X_train = X_train.drop(["reference_category_1", "reference_category_2"], axis=1)
X_test = X_test.drop(["reference_category_1", "reference_category_2"], axis=1)

# %%
model = CustomCatboostClassifier(min_frequency=10_000, category_features=[])

# %%
metadata_df.columns
# Out:
# Index(['arxiv_id', 'date', 'title', 'authors', 'abstract', 'category_1',
#        'category_2', 'citation_count', 'influential_citation_count', 'tldr'],
#       dtype='object')

# %%
fit_metadata = metadata_df[
    [
        "title",
        "abstract",
        # "category_1",
        # "category_2",
        "citation_count",
        "influential_citation_count",
    ]
]
# fit_metadata.loc[:, 'category_1'] = fit_metadata['category_1'].fillna('')
# fit_metadata.loc[:, 'category_2'] = fit_metadata['category_2'].fillna('')
# 
# # Create a mask where categories are infrequent
# mask_1 = fit_metadata['category_1'].isin(infrequent_categories_set)
# mask_2 = fit_metadata['category_2'].isin(infrequent_categories_set)
# 
# # Use where or mask to replace
# fit_metadata['category_1'] = fit_metadata['category_1'].where(~mask_1, other='other')
# fit_metadata['category_2'] = fit_metadata['category_2'].where(~mask_2, other='other')

fit_metadata = fit_metadata.iloc[:5000]
model.fit(X_train, y_train, fit_metadata, verbose=True)
# Out:
# 2024-05-05 23:33:03.764 | INFO     | citations_searcher.models.custom_catboost:fit:59 - Fitting the catboost model...
# Learning rate set to 0.024172
# 0:	learn: 0.6828847	total: 29.7ms	remaining: 29.7s
# 1:	learn: 0.6732400	total: 55.2ms	remaining: 27.5s
# 2:	learn: 0.6640338	total: 82.3ms	remaining: 27.3s
# 3:	learn: 0.6550546	total: 108ms	remaining: 26.8s
# 4:	learn: 0.6465147	total: 134ms	remaining: 26.7s
# 5:	learn: 0.6384968	total: 159ms	remaining: 26.3s
# 6:	learn: 0.6312760	total: 186ms	remaining: 26.3s
# 7:	learn: 0.6245106	total: 213ms	remaining: 26.4s
# 8:	learn: 0.6175249	total: 242ms	remaining: 26.7s
# 9:	learn: 0.6113969	total: 271ms	remaining: 26.9s
# 10:	learn: 0.6052578	total: 296ms	remaining: 26.6s
# 11:	learn: 0.5995575	total: 320ms	remaining: 26.4s
# 12:	learn: 0.5944428	total: 345ms	remaining: 26.2s
# 13:	learn: 0.5896460	total: 371ms	remaining: 26.1s
# 14:	learn: 0.5846290	total: 395ms	remaining: 25.9s
# 15:	learn: 0.5799356	total: 419ms	remaining: 25.8s
# 16:	learn: 0.5756637	total: 445ms	remaining: 25.7s
# 964:	learn: 0.3689808	total: 19.3s	remaining: 701ms
# 965:	learn: 0.3689410	total: 19.3s	remaining: 681ms
# 966:	learn: 0.3688481	total: 19.4s	remaining: 661ms
# 967:	learn: 0.3687711	total: 19.4s	remaining: 641ms
# 968:	learn: 0.3687443	total: 19.4s	remaining: 621ms
# 969:	learn: 0.3686717	total: 19.4s	remaining: 601ms
# 970:	learn: 0.3685988	total: 19.4s	remaining: 581ms
# 971:	learn: 0.3685764	total: 19.5s	remaining: 561ms
# 972:	learn: 0.3684558	total: 19.5s	remaining: 541ms
# 973:	learn: 0.3684143	total: 19.5s	remaining: 521ms
# 974:	learn: 0.3683565	total: 19.5s	remaining: 501ms
# 975:	learn: 0.3683268	total: 19.6s	remaining: 481ms
# 976:	learn: 0.3682549	total: 19.6s	remaining: 461ms
# 977:	learn: 0.3681720	total: 19.6s	remaining: 441ms
# 978:	learn: 0.3680952	total: 19.6s	remaining: 421ms
# 979:	learn: 0.3680751	total: 19.6s	remaining: 401ms
# 980:	learn: 0.3680355	total: 19.7s	remaining: 381ms
# 981:	learn: 0.3679869	total: 19.7s	remaining: 361ms
# 982:	learn: 0.3679389	total: 19.7s	remaining: 341ms
# 983:	learn: 0.3678461	total: 19.7s	remaining: 321ms
# 984:	learn: 0.3678252	total: 19.7s	remaining: 301ms
# 985:	learn: 0.3677615	total: 19.8s	remaining: 280ms
# 986:	learn: 0.3677183	total: 19.8s	remaining: 260ms
# 987:	learn: 0.3676253	total: 19.8s	remaining: 240ms
# 988:	learn: 0.3675627	total: 19.8s	remaining: 220ms
# 989:	learn: 0.3675215	total: 19.8s	remaining: 200ms
# 990:	learn: 0.3673965	total: 19.9s	remaining: 180ms
# 991:	learn: 0.3673744	total: 19.9s	remaining: 160ms
# 992:	learn: 0.3673343	total: 19.9s	remaining: 140ms
# 993:	learn: 0.3673085	total: 19.9s	remaining: 120ms
# 994:	learn: 0.3672344	total: 19.9s	remaining: 100ms
# 995:	learn: 0.3672057	total: 19.9s	remaining: 80.1ms
# 996:	learn: 0.3671871	total: 20s	remaining: 60.1ms
# 997:	learn: 0.3671497	total: 20s	remaining: 40ms
# 998:	learn: 0.3671227	total: 20s	remaining: 20ms
# 999:	learn: 0.3670534	total: 20s	remaining: 0us
# 2024-05-05 23:34:16.704 | INFO     | citations_searcher.models.custom_catboost:fit:61 - Successfully fitted!
# 2024-05-05 23:34:16.705 | INFO     | citations_searcher.models.custom_catboost:fit:63 - Fitting vectorizer...
# 2024-05-05 23:34:17.667 | INFO     | citations_searcher.models.custom_catboost:fit:67 - Successfully fitted!

# %%
test = X_test.iloc[0:1][['paper_title', 'paper_abstract']]
test = test.rename(columns={'paper_title': 'title', 'paper_abstract': 'abstract'})

# %%
test = test.reset_index(drop=True)
test
# Out:
#                                                title  \
# 0  analysing the noise model error for realistic ...
#
#                                             abstract
# 0  distant and weak supervision allow to obtain l...

# %%
res = model.predict(test, n_predictions=10, n_candidates=100)
fit_metadata.loc[res.reshape(-1,)]
# Out:
#                                                   title  \
# 3415  revisiting self-training for neural sequence g...
# 4991  eternal sunshine of the spotless net: selectiv...
# 3328  unsupervised domain adaptation through self-su...
# 3555  self: learning to filter noisy labels with sel...
# 1701               deep self-learning from noisy labels
# 137   does learning require memorization? a short ta...
# 4607  confident learning: estimating uncertainty in ...
# 2059  symmetric cross entropy for robust learning wi...
# 1002  generative modeling by estimating gradients of...
# 4943  self-training with noisy student improves imag...
#
#                                                abstract  citation_count  \
# 3415  self-training is one of the earliest and simpl...           241.0
# 4991  we explore the problem of selectively forgetti...           260.0
# 3328  this paper addresses unsupervised domain adapt...           225.0
# 3555  deep neural networks (dnns) have been shown to...           252.0
# 1701  convnets achieve good results when training fr...           238.0
# 137   state-of-the-art results on image recognition ...           345.0
# 4607  learning exists in the context of data, yet no...           483.0
# 2059  training accurate deep neural networks (dnns) ...           674.0
# 1002  we introduce a new generative model where samp...          2164.0
# 4943  we present noisy student training, a semi-supe...          2002.0
#
#       influential_citation_count
# 3415                        30.0
# 4991                        57.0
# 3328                        19.0
# 3555                        20.0
# 1701                        17.0
# 137                         34.0
# 4607                        71.0
# 2059                       135.0
# 1002                       283.0
# 4943                       236.0

# %%
X_test.head()
# Out:
#                                               paper_title  \
# 319141  analysing the noise model error for realistic ...
# 77476   ncore: neural counterfactual representation le...
# 348095  successor feature landmarks for long-horizon g...
# 200574  mime: mimicking centralized stochastic algorit...
# 482717               declarative machine learning systems
#
#                                            paper_abstract  \
# 319141  distant and weak supervision allow to obtain l...
# 77476   estimating an individual's potential response ...
# 348095  operating in the real-world often requires age...
# 200574  federated learning (fl) is a challenging setti...
# 482717  in the last years machine learning (ml) has mo...
#
#                                           reference_title  \
# 319141  performance analysis and comparison of distrib...
# 77476   causal effect inference with deep latent-varia...
# 348095  graphact: accelerating gcn training on cpu-fpg...
# 200574           leaf: a benchmark for federated settings
# 482717  normalization techniques in training dnns: met...
#
#                                        reference_abstract  \
# 319141  deep learning has permeated through many aspec...
# 77476   learning individual-level causal effects from ...
# 348095  graph convolutional networks (gcns) have emerg...
# 200574  modern federated networks, such as those compr...
# 482717  normalization techniques are essential for acc...
#
#         reference_citation_count  reference_influential_citation_count
# 319141                      23.0                                   0.0
# 77476                      589.0                                 130.0
# 348095                     101.0                                   9.0
# 200574                    1073.0                                 276.0
# 482717                     118.0                                   5.0

# %%
predictions = model._validation_predict(X_test)
# Out:
# 2024-05-05 23:34:18.145 | INFO     | citations_searcher.models.custom_catboost:_validation_predict:137 - Making validating predictions for 105778 objects...
# 2024-05-05 23:34:20.473 | INFO     | citations_searcher.models.custom_catboost:_validation_predict:139 - Validating predictions generated!

# %%
from citations_searcher.metrics import evaluate_predictions

# %%
evaluate_predictions(predictions, y_test)
# Out:
# 2024-05-05 23:34:20.592 | INFO     | citations_searcher.metrics.evaluate_predictions:evaluate_predictions:30 - Train scores. accuracy_score: 0.843; precision_score: 0.883; recall_score: 0.843; f1_score: 0.863;
# {'accuracy_score': 0.8428312125394695,
#  'precision_score': 0.8831340178284477,
#  'recall_score': 0.8431030584891644,
#  'f1_score': 0.8626543847329505}
